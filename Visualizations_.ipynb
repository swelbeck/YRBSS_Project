# %% [markdown]
# # Visualizations

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = [10,5]

pd.set_option('display.max_columns', 150, 'display.max_rows', 150)

# %%
#Read in data
df = pd.read_csv('final_df alex.csv')

# %% [markdown]
# **Descriptive Statistics**

# %%
#General look at descriptive statistics for all columns
df.describe()
# Out:
#          Unnamed: 0          YEAR       raceeth  How old are you  \
# count  53548.000000  53548.000000  53548.000000     53548.000000
# mean   26773.500000   2014.679092      5.126653         5.087286
# std    15458.120444      2.815448      1.510659         1.228198
# min        0.000000   2011.000000      1.000000         1.000000
# 25%    13386.750000   2013.000000      5.000000         4.000000
# 50%    26773.500000   2015.000000      5.000000         5.000000
# 75%    40160.250000   2017.000000      6.000000         6.000000
# max    53547.000000   2019.000000      8.000000         7.000000
#
#        What is your sex  In what grade are you  How tall are you  \
# count      53548.000000           53548.000000      53548.000000
# mean           1.481829               2.480541          1.688293
# std            0.499674               1.121861          0.098875
# min            1.000000               1.000000          1.270000
# 25%            1.000000               1.000000          1.630000
# 50%            1.000000               2.000000          1.680000
# 75%            2.000000               3.000000          1.750000
# max            2.000000               5.000000          2.110000
#
#        How much do you weigh  Seat belt use  Riding with a drinking driver  \
# count           53548.000000   53548.000000                   53548.000000
# mean               67.017479       4.352338                       1.388493
# std                16.683080       0.939576                       0.914615
# min                24.950000       1.000000                       1.000000
# 25%                56.700000       4.000000                       1.000000
# 50%                62.600000       5.000000                       1.000000
# 75%                74.840000       5.000000                       1.000000
# max               180.990000       5.000000                       5.000000
#
#        Drinking and driving  Weapon carrying  Weapon carrying at school  \
# count          53548.000000     53548.000000               53548.000000
# mean               1.519328         1.408661                   1.103533
# std                0.702596         1.094574                   0.584567
# min                1.000000         1.000000                   1.000000
# 25%                1.000000         1.000000                   1.000000
# 50%                1.000000         1.000000                   1.000000
# 75%                2.000000         1.000000                   1.000000
# max                6.000000         5.000000                   5.000000
#
#        Safety concerns at school  Threatened at school  Physical fighting  \
# count               53548.000000          53548.000000       53548.000000
# mean                    1.109715              1.141219           1.520169
# std                     0.498348              0.727962           1.216012
# min                     1.000000              1.000000           1.000000
# 25%                     1.000000              1.000000           1.000000
# 50%                     1.000000              1.000000           1.000000
# 75%                     1.000000              1.000000           1.000000
# max                     5.000000              8.000000           8.000000
#
#        Physical fighting at school  Forced sexual intercourse  \
# count                 53548.000000               53548.000000
# mean                      1.138156                   1.927374
# std                       0.613862                   0.259525
# min                       1.000000                   1.000000
# 25%                       1.000000                   2.000000
# 50%                       1.000000                   2.000000
# 75%                       1.000000                   2.000000
# max                       8.000000                   2.000000
#
#        Bullying at school  Electronic bullying  Sad or hopeless  \
# count        53548.000000         53548.000000     53548.000000
# mean             1.811291             1.854560         1.677990
# std              0.391281             0.352547         0.467251
# min              1.000000             1.000000         1.000000
# 25%              2.000000             2.000000         1.000000
# 50%              2.000000             2.000000         2.000000
# 75%              2.000000             2.000000         2.000000
# max              2.000000             2.000000         2.000000
#
#        Considered suicide  Made a suicide plan  Attempted suicide  \
# count        53548.000000         53548.000000       53548.000000
# mean             1.824998             1.855849           1.140453
# std              0.379972             0.351246           0.538586
# min              1.000000             1.000000           1.000000
# 25%              2.000000             2.000000           1.000000
# 50%              2.000000             2.000000           1.000000
# 75%              2.000000             2.000000           1.000000
# max              2.000000             2.000000           5.000000
#
#        Injurious suicide attempt  Ever cigarette use  \
# count               53548.000000        53548.000000
# mean                    1.131284            1.671080
# std                     0.470844            0.469825
# min                     1.000000            1.000000
# 25%                     1.000000            1.000000
# 50%                     1.000000            2.000000
# 75%                     1.000000            2.000000
# max                     3.000000            2.000000
#
#        Initiation of cigarette smoking  Current cigarette use  \
# count                     53548.000000           53548.000000
# mean                          2.055726               1.348248
# std                           1.884897               1.184557
# min                           1.000000               1.000000
# 25%                           1.000000               1.000000
# 50%                           1.000000               1.000000
# 75%                           2.000000               1.000000
# max                           7.000000               7.000000
#
#        Current smokeless tobacco use  Current cigar use  \
# count                   53548.000000       53548.000000
# mean                        1.173527           1.217394
# std                         0.870642           0.851894
# min                         1.000000           1.000000
# 25%                         1.000000           1.000000
# 50%                         1.000000           1.000000
# 75%                         1.000000           1.000000
# max                         7.000000           7.000000
#
#        Initiation of alcohol use  Current alcohol use  Source of alcohol  \
# count               53548.000000         53548.000000       53548.000000
# mean                    3.429316             1.576417           2.541570
# std                     2.188578             1.070177           2.454069
# min                     1.000000             1.000000           1.000000
# 25%                     1.000000             1.000000           1.000000
# 50%                     4.000000             1.000000           1.000000
# 75%                     5.000000             2.000000           5.000000
# max                     7.000000             7.000000           8.000000
#
#        Ever marijuana use  Initiation of marijuana use  Current marijuana use  \
# count        53548.000000                 53548.000000           53548.000000
# mean             2.324419                     2.699186               1.572085
# std              2.050970                     2.191601               1.282910
# min              1.000000                     1.000000               1.000000
# 25%              1.000000                     1.000000               1.000000
# 50%              1.000000                     1.000000               1.000000
# 75%              3.000000                     5.000000               1.000000
# max              7.000000                     7.000000               6.000000
#
#        Ever steroid use  Illegal injected drug use  Illegal drugs at school  \
# count      53548.000000               53548.000000             53548.000000
# mean           1.057444                   1.018152                 1.766359
# std            0.444195                   0.177988                 0.423150
# min            1.000000                   1.000000                 1.000000
# 25%            1.000000                   1.000000                 2.000000
# 50%            1.000000                   1.000000                 2.000000
# 75%            1.000000                   1.000000                 2.000000
# max            6.000000                   3.000000                 2.000000
#
#        Ever sexual intercourse  Sex before 13 years  Multiple sex partners  \
# count             53548.000000         53548.000000           53548.000000
# mean                  1.571917             2.992007               2.145346
# std                   0.494806             2.505909               1.773185
# min                   1.000000             1.000000               1.000000
# 25%                   1.000000             1.000000               1.000000
# 50%                   2.000000             1.000000               1.000000
# 75%                   2.000000             5.000000               3.000000
# max                   2.000000             8.000000               7.000000
#
#        Current sexual activity  Alcohol/drugs and sex    Condom use  \
# count             53548.000000           53548.000000  53548.000000
# mean                  1.896934               1.786341      1.606876
# std                   1.278619               0.933065      0.763048
# min                   1.000000               1.000000      1.000000
# 25%                   1.000000               1.000000      1.000000
# 50%                   1.000000               1.000000      1.000000
# 75%                   3.000000               3.000000      2.000000
# max                   8.000000               3.000000      3.000000
#
#        Birth control pill use  Perception of weight   Weight loss  \
# count            53548.000000          53548.000000  53548.000000
# mean                 2.300627              3.206488      2.021831
# std                  1.805916              0.779903      1.163381
# min                  1.000000              1.000000      1.000000
# 25%                  1.000000              3.000000      1.000000
# 50%                  1.000000              3.000000      2.000000
# 75%                  4.000000              4.000000      3.000000
# max                  8.000000              5.000000      4.000000
#
#        Television watching  Computer use   HIV testing        Asthma  \
# count         53548.000000  53548.000000  53548.000000  53548.000000
# mean              3.443079      4.081889      1.991111      1.821506
# std               1.808349      2.097703      0.441633      0.470584
# min               1.000000      1.000000      1.000000      1.000000
# 25%               2.000000      2.000000      2.000000      2.000000
# 50%               3.000000      4.000000      2.000000      2.000000
# 75%               5.000000      6.000000      2.000000      2.000000
# max               7.000000      7.000000      3.000000      3.000000
#
#               Sleep  Ever used LSD        BMIPCT        weight       stratum  \
# count  53548.000000   53548.000000  5.354800e+04  53548.000000  53548.000000
# mean       3.656439       1.109416  6.213372e+01      1.082591    164.717002
# std        1.307949       0.538331  2.784126e+01      0.941813     50.440779
# min        1.000000       1.000000  2.039970e-08      0.028600    101.000000
# 25%        3.000000       1.000000  4.429519e+01      0.463000    104.000000
# 50%        4.000000       1.000000  6.516580e+01      0.845100    201.000000
# 75%        5.000000       1.000000  8.760221e+01      1.386600    211.000000
# max        7.000000       6.000000  9.996470e+01     10.678100    214.000000
#
#                  psu  Has used hard drugs  healthy_eating  regular_activity
# count   53548.000000         53548.000000    53548.000000      53548.000000
# mean   264860.247479             0.220662        0.945003          0.752783
# std    178287.459596             0.414697        0.227977          0.431398
# min     10530.000000             0.000000        0.000000          0.000000
# 25%     88352.000000             0.000000        1.000000          1.000000
# 50%    240330.000000             0.000000        1.000000          1.000000
# 75%    417702.000000             0.000000        1.000000          1.000000
# max    787890.000000             1.000000        1.000000          1.000000

# %% [markdown]
# **Stacked bar-chart for condom use by age group**
#
# From the visualization we can see that she share of respondants who used a condom that last time that had sexual intercourse increases with age. This share is the most wide at 17 years old.

# %%
# Passenger class summary
print('Condom Usage by Age Group: \nThe last time you had sexual intercourse, did you or your partner use a condom?')

print('\n')
print(df.groupby(['How old are you','Condom use'])['How old are you'].count().unstack())

# Passenger class visualization
age = df.groupby(['How old are you','Condom use'])['How old are you'].count().unstack()
p1 = age.plot(kind = 'bar', stacked = True, 
                   title = 'Condom Usage by Age Group', 
                color = ['red','pink','grey'], alpha = .70)
x = [0,1,2,3,4,5,6]
labels = ['12 or younger','13','14','15','16','17','18 or older']
p1.set_xlabel('Age')
p1.set_ylabel('# of respondants')
plt.xticks(x, labels,rotation = 45)

p1.legend(['Never had sex','Did use condom','Did not use condom'])

plt.show()
# Out:
# Condom Usage by Age Group:
# The last time you had sexual intercourse, did you or your partner use a c
# ondom?
#
#
# Condom use        1.0   2.0   3.0
# How old are you
# 1.0                 7    14    33
# 2.0                36     7     3
# 3.0              4600   693   386
# 4.0              9051  2379  1309
# 5.0              7672  3689  2206
# 6.0              6121  4563  3117
# 7.0              2765  2750  2147

# %% [markdown]
# **Condom Use Over Time**
#
# This visualization shows us that over time the share of respondants who did use a condom has become narrower.

# %%
# Passenger class summary
print('Condom Use Over Time: \nThe last time you had sexual intercourse, did you or your partner use a condom?')

print('\n')
print(df.groupby(['YEAR','Condom use'])['YEAR'].count().unstack())

# Passenger class visualization
age = df.groupby(['YEAR','Condom use'])['YEAR'].count().unstack()
p1 = age.plot(kind = 'bar', stacked = True, 
                   title = 'Condom Use Over Time', 
                   color = ['red','pink','grey'], alpha = .70)
p1.set_xlabel('YEAR')
plt.xticks(rotation = 45)
p1.set_ylabel('# of respondants')
p1.legend(['Never had sex','Did use condom','Did not use condom'])
plt.show()
# Out:
# Condom Use Over Time:
# The last time you had sexual intercourse, did you or your partner use a condom?
#
#
# Condom use   1.0   2.0   3.0
# YEAR
# 2011.0      6380  3936  2240
# 2013.0      5920  3351  2060
# 2015.0      6323  2708  1822
# 2017.0      5976  2174  1615
# 2019.0      5653  1926  1464

# %% [markdown]
# **Age Groups Under the Influence During Sex**
#
# The graph below shows us the those who have had sex under the influence per age group is relatively small.

# %%
# Passenger class summary
print('Alcohol/drugs and sex: \nDid you drink alcohol or use drugs before you had sexual intercourse the last time?')

print('\n')
print(df.groupby(['How old are you','Alcohol/drugs and sex'])['How old are you'].count().unstack())

# Passenger class visualization
age = df.groupby(['How old are you','Alcohol/drugs and sex'])['How old are you'].count().unstack()
p1 = age.plot(kind = 'bar', stacked = True, 
                   title = 'Age Groups Under the Influence During Sex', 
                   color = ['red','pink','grey'], alpha = .70)
x = [0,1,2,3,4,5,6]
labels = ['12 or younger','13','14','15','16','17','18 or older']
plt.xticks(x, labels,rotation = 45)
p1.set_xlabel('Age')
p1.set_ylabel('# of Respondants')
p1.legend(['Never had sex','Was under the influence','Was not under the influence'])
plt.show()
# Out:
# Alcohol/drugs and sex:
# Did you drink alcohol or use drugs before you had sexual intercourse the last time?
#
#
# Alcohol/drugs and sex   1.0   2.0   3.0
# How old are you
# 1.0                       7    29    18
# 2.0                      36     3     7
# 3.0                    4600   175   904
# 4.0                    9051   674  3014
# 5.0                    7672  1078  4817
# 6.0                    6121  1489  6191
# 7.0                    2765  1037  3860

# %%
# Passenger class summary
print('Alcohol/drugs and sex')

print('\n')
print(df.groupby(['How old are you','Ever sexual intercourse'])['How old are you'].count().unstack())

# Passenger class visualization
age = df.groupby(['How old are you','Ever sexual intercourse'])['How old are you'].count().unstack()
p1 = age.plot(kind = 'bar', stacked = True, 
                   title = 'Condom Use by Age', 
                   color = ['red','pink','grey'], alpha = .70)
p1.set_xlabel('Age')
x = [0,1,2,3,4,5,6]
labels = ['12 or younger','13','14','15','16','17','18 or older']
plt.xticks(x, labels,rotation = 45)
p1.set_ylabel('# of respondants')
p1.legend(['Yes','No'])
plt.show()
# Out:
# Alcohol/drugs and sex
#
#
# Ever sexual intercourse   1.0   2.0
# How old are you
# 1.0                        46     8
# 2.0                         9    37
# 3.0                      1060  4619
# 4.0                      3625  9114
# 5.0                      5773  7794
# 6.0                      7575  6226
# 7.0                      4835  2827
